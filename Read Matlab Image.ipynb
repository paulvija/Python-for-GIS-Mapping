# %% [markdown]
# ## Read matlab image and plot using Python

# %% [markdown]
# MAT image coutesey : vuw

# %% [markdown]
# <h3 id="Vijay-Paul"><a href="mailto:vijay.paul@niwa.co.nz">Vijay Paul</a></h3>

# %%
# !date
# Out:
# Thu 30 Jul 2015 22:04:31 NZST

# %% [markdown]
# ### Library imports

# %%
from scipy.io import loadmat
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np

# %%
#import mpld3
#from mpld3 import plugins
#mpld3.enable_notebook()

# %% [markdown]
# ### Locate and load matlab image

# %%
mat_file = loadmat("/Users/vijaypaul/Documents/GEOG 315/GEOG315_LAB1/tasman_gscale.mat")

# %%
#matlab header info plus array in dictionary format
mat_file
# Out:
# {'__globals__': [],
#  '__header__': 'MATLAB 5.0 MAT-file, Platform: MACI64, Created on: Tue Aug 20 14:51:41 2013',
#  '__version__': '1.0',
#  'sMat': array([[26103, 25628, 25628, ..., 31151, 32983, 30218],
#         [25628, 26725, 26725, ..., 29743, 37856, 32672],
#         [27923, 24696, 24073, ..., 26679, 32672, 32983],
#         ...,
#         [11250,  9385,  9385, ..., 29891, 36862, 38269],
#         [ 9385,  9385, 14778, ..., 27612, 27612, 30366],
#         [14778, 15252, 15252, ..., 36240, 35929, 33430]], dtype=uint16)}

# %% [markdown]
# ### Plot 'sMat' array using imshow

# %%
mat_array = mat_file['sMat']

# %%
print mat_array.shape
# Out:
# (1000, 1500)

# %%
# Gray Image
fig,ax = plt.subplots(figsize=(8,8))
plt.imshow(mat_array, cmap = plt.get_cmap('gray'))
ax.set_title('Tasman Image Grey')
#plugins.clear(fig)  # clear all plugins from the figure
#plugins.connect(fig, plugins.Reset(), plugins.Zoom(), plugins.MousePosition(fontsize=16, fmt='.4g'))
plt.tight_layout()
plt.show()

# %%
mat_array[1,0:].shape # all the columns in row 2
# Out:
# (1500,)

# %%
mat_array[:,1].shape # all the rows in column 2
# Out:
# (1000,)

# %%
cols = mat_array[mat_array[:,0:] > 500]

# %%
rows = mat_array[mat_array[0:,:] > 500]

# %%
jj = mat_array[np.where (mat_array > 500) ]
jj.shape
# Out:
# (1499992,)

# %%
fig,ax = plt.subplots(figsize=(10,10))
plt.imshow(mat_array, cmap = plt.get_cmap('gray'), interpolation='bilinear')
plt.contour(mat_array, [0, 8000], colors = 'red')
plt.show()
